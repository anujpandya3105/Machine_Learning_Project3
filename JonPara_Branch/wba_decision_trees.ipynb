# %%
# Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn import preprocessing

# %matplotlib inline

# %%
full_df = pd.read_csv("full_data.csv")
full_df.head()
# Out:
#    Unnamed: 0  Total_Insured        County_State  Total_Uninsured  Year  \
# 0           0          43075  Autauga County, AL             4002  2016
# 1           1         148007  Baldwin County, AL            17733  2016
# 2           2          15745  Barbour County, AL             2252  2016
# 3           3          15358     Bibb County, AL             1646  2016
# 4           4          41382   Blount County, AL             5704  2016
#
#    State_Code  County_Code  Poverty_percent_in_County  \
# 0           1            1                       13.5
# 1           1            3                       11.7
# 2           1            5                       29.9
# 3           1            7                       20.1
# 4           1            9                       14.1
#
#    Total_Poverty_in_County  Uninsured_percent
# 0                     7444           8.500967
# 1                    24005          10.699288
# 2                     6787          12.513197
# 3                     4099           9.680075
# 4                     8033          12.114004

# %%
full_df.columns
# Out:
# Index(['Unnamed: 0', 'Total_Insured', 'County_State', 'Total_Uninsured',
#        'Year', 'State_Code', 'County_Code', 'Poverty_percent_in_County',
#        'Total_Poverty_in_County', 'Uninsured_percent'],
#       dtype='object')

# %%
# Clean data to separate State and County. Use this later in Tableau and predictive analysis

full_df['State'] = full_df['County_State'].apply(lambda State: State.split(',')[-1])
full_df['County'] = full_df['County_State'].apply(lambda State: State.split(',')[0])
full_df.head()
# Out:
#    Unnamed: 0  Total_Insured        County_State  Total_Uninsured  Year  \
# 0           0          43075  Autauga County, AL             4002  2016
# 1           1         148007  Baldwin County, AL            17733  2016
# 2           2          15745  Barbour County, AL             2252  2016
# 3           3          15358     Bibb County, AL             1646  2016
# 4           4          41382   Blount County, AL             5704  2016
#
#    State_Code  County_Code  Poverty_percent_in_County  \
# 0           1            1                       13.5
# 1           1            3                       11.7
# 2           1            5                       29.9
# 3           1            7                       20.1
# 4           1            9                       14.1
#
#    Total_Poverty_in_County  Uninsured_percent State          County
# 0                     7444           8.500967    AL  Autauga County
# 1                    24005          10.699288    AL  Baldwin County
# 2                     6787          12.513197    AL  Barbour County
# 3                     4099           9.680075    AL     Bibb County
# 4                     8033          12.114004    AL   Blount County

# %%
full_df = full_df[['Unnamed: 0', 'Total_Insured',"County", "State", 'Total_Uninsured',
       'Year', 'State_Code', 'County_Code', 'Poverty_percent_in_County',
       'Total_Poverty_in_County', 'Uninsured_percent']]

# %%
full_df.head()
# Out:
#    Unnamed: 0  Total_Insured          County State  Total_Uninsured  Year  \
# 0           0          43075  Autauga County    AL             4002  2016
# 1           1         148007  Baldwin County    AL            17733  2016
# 2           2          15745  Barbour County    AL             2252  2016
# 3           3          15358     Bibb County    AL             1646  2016
# 4           4          41382   Blount County    AL             5704  2016
#
#    State_Code  County_Code  Poverty_percent_in_County  \
# 0           1            1                       13.5
# 1           1            3                       11.7
# 2           1            5                       29.9
# 3           1            7                       20.1
# 4           1            9                       14.1
#
#    Total_Poverty_in_County  Uninsured_percent
# 0                     7444           8.500967
# 1                    24005          10.699288
# 2                     6787          12.513197
# 3                     4099           9.680075
# 4                     8033          12.114004

# %% [markdown]
# ## Train Test Split

# %%
# Change name of dataframe

insurance_df = full_df

# %%
# Categorical features since they don't have integers or floats in columns 

cat_feats_1 = ['County', "State"]

# %%
insurance_data = pd.get_dummies(cat_feats_1, drop_first = True)

# %%
# Create X and y variables to train and test data. 

X = insurance_df.drop('Total_Uninsured',axis=1)
y = insurance_df['Total_Uninsured']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
le = preprocessing.LabelEncoder()
balance_data = insurance_df.apply(le.fit_transform)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-51c4b4d79f89> in <module>()
#       1 dtree = DecisionTreeClassifier()
# ----> 2 dtree.fit(X_train, y_train)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: ' IA'
